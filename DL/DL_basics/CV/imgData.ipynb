# %% [markdown]
# # 이미지 데이터 이해
#
# <img src="../CV/assets/img/imgdata1.png" style="width: 800px; height: ;">
#
# <br>
# <br>
#
#
# <img src="../CV/assets/img/imgdata2.png" style="width: 800px; height: ;">
#
# #### *"인간의 시각작용에서 input값은 빛, 컴퓨터의 이미지 분석에서의 input값은 데이터"*
#
# <br>
# <br>
#
#
# <img src="../CV/assets/img/imgdata3.png" style="width: 800px; height: ;">
#
# #### *"컴퓨터는 하나의 픽셀과 주변 픽셀과의 관계(값이 비슷하다? 같다? 다르다?)를 통해, 특징, 형태 등을 파악"*
# #### *"유사성을 비교함으로써 이미지에 있는 정보를 추론해 낼 수 있음"*
#
# <br>
# <br>
#
#
#
# ### Classification
#
# <img src="../CV/assets/img/imgdata4.png" style="width: 800px; height: ;">
#
# ### **single object**
#
# - **Classification (분류):**
# 분류는 컴퓨터 비전 분야에서 주어진 입력 이미지를 사전에 정의된 클래스 레이블 중 하나로 분류하는 작업
#
# - **Localization:**
# 특정한 객체가 하나의 이미지안에서 어디에 있는지 Bounding Box로 지정해주는 작업
#
# <br>
# <br>
#
#
#
# ## Multiple objects
#
# <img src="../CV/assets/img/imgdata5.png" style="width: 800px; height: ;">
#
# #### Object Detection(BBOX + Classification)
#
# - 이미지 내, 객체를 검출
#
# - 각 객체의 위치와 BBox를 표시
#
# - 각 객체의 클래스 레이블을 붙히는 작업
#
#
# <br>
# <br>
#
#
#
# ## Segmentation
#
# <img src="../CV/assets/img/imgdata6.png" style="width: 800px; height: ;">
#
# - 픽셀 단위에서 클래스를 찾는 태스크
#
# - 이미지를 작은 영역으로 나누고 각 영역을 객체 또는 배경으로 분류
#
# - Semantic Segmentation은 픽셀을 객체의 클래스로 분류하여 이미지를 분할
#
# - Instance Segmentation은 개별 객체들을 개별적으로 식별하여 분할, 객체 간의 겹침과 부분적 가려짐 문제를 처리함으로서 보다 정확한 객체 분할을 제공
